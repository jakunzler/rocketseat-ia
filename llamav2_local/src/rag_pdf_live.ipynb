# %%
pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: aiofiles==23.2.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 1)) (23.2.1)
# Requirement already satisfied: aiohttp==3.8.5 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 2)) (3.8.5)
# Requirement already satisfied: aiosignal==1.3.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: altair==5.0.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 4)) (5.0.1)
# Requirement already satisfied: annotated-types==0.5.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 5)) (0.5.0)
# Requirement already satisfied: anyio==3.7.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 6)) (3.7.1)
# Requirement already satisfied: appnope==0.1.3 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 7)) (0.1.3)
# Requirement already satisfied: asttokens==2.2.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 8)) (2.2.1)
# Requirement already satisfied: async-timeout==4.0.3 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 9)) (4.0.3)
# Requirement already satisfied: attrs==23.1.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 10)) (23.1.0)
# Requirement already satisfied: backcall==0.2.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: backoff==2.2.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 12)) (2.2.1)
# Requirement already satisfied: bcrypt==4.0.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 13)) (4.0.1)
# Requirement already satisfied: certifi==2023.7.22 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 14)) (2023.7.22)
# Requirement already satisfied: charset-normalizer==3.2.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 15)) (3.2.0)
# Requirement already satisfied: chroma-hnswlib==0.7.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 16)) (0.7.2)
# Requirement already satisfied: chromadb==0.4.7 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 17)) (0.4.7)
# Requirement already satisfied: click==8.1.7 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 18)) (8.1.7)
# Requirement already satisfied: coloredlogs==15.0.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 19)) (15.0.1)
# Requirement already satisfied: comm==0.1.4 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 20)) (0.1.4)
# Requirement already satisfied: contourpy==1.1.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 21)) (1.1.0)
# Requirement already satisfied: cycler==0.11.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 22)) (0.11.0)
# Requirement already satisfied: dataclasses-json==0.5.14 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 23)) (0.5.14)
# Requirement already satisfied: debugpy==1.6.7.post1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 24)) (1.6.7.post1)
# Requirement already satisfied: decorator==5.1.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 25)) (5.1.1)
# Requirement already satisfied: diskcache==5.6.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 26)) (5.6.1)
# Requirement already satisfied: executing==1.2.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 27)) (1.2.0)
# Requirement already satisfied: fastapi==0.99.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 28)) (0.99.1)
# Requirement already satisfied: ffmpy==0.3.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 29)) (0.3.1)
# Requirement already satisfied: filelock==3.12.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 30)) (3.12.2)
# Requirement already satisfied: flatbuffers==23.5.26 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 31)) (23.5.26)
# Requirement already satisfied: fonttools==4.42.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 32)) (4.42.1)
# Requirement already satisfied: frozenlist==1.4.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 33)) (1.4.0)
# Requirement already satisfied: fsspec==2023.6.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 34)) (2023.6.0)
# Requirement already satisfied: gradio==3.41.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 35)) (3.41.2)
# Requirement already satisfied: gradio_client==0.5.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 36)) (0.5.0)
# Requirement already satisfied: greenlet==2.0.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 37)) (2.0.2)
# Requirement already satisfied: h11==0.14.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 38)) (0.14.0)
# Requirement already satisfied: httpcore==0.17.3 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 39)) (0.17.3)
# Requirement already satisfied: httptools==0.6.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 40)) (0.6.0)
# Requirement already satisfied: httpx==0.24.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 41)) (0.24.1)
# Requirement already satisfied: huggingface-hub==0.16.4 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 42)) (0.16.4)
# Requirement already satisfied: humanfriendly==10.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 43)) (10.0)
# Requirement already satisfied: idna==3.4 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 44)) (3.4)
# Requirement already satisfied: importlib-resources==6.0.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 45)) (6.0.1)
# Requirement already satisfied: ipykernel==6.25.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 46)) (6.25.1)
# Requirement already satisfied: ipython==8.14.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 47)) (8.14.0)
# Requirement already satisfied: ipywidgets==8.1.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 48)) (8.1.0)
# Requirement already satisfied: jedi==0.19.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 49)) (0.19.0)
# Requirement already satisfied: Jinja2==3.1.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 50)) (3.1.2)
# Requirement already satisfied: joblib==1.3.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 51)) (1.3.2)
# Requirement already satisfied: jsonschema==4.19.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 52)) (4.19.0)
# Requirement already satisfied: jsonschema-specifications==2023.7.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 53)) (2023.7.1)
# Requirement already satisfied: jupyter_client==8.3.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 54)) (8.3.0)
# Requirement already satisfied: jupyter_core==5.3.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 55)) (5.3.1)
# Requirement already satisfied: jupyterlab-widgets==3.0.8 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 56)) (3.0.8)
# Requirement already satisfied: kiwisolver==1.4.5 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 57)) (1.4.5)
# Requirement already satisfied: langchain==0.0.274 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 58)) (0.0.274)
# Requirement already satisfied: langsmith==0.0.26 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 59)) (0.0.26)
# Requirement already satisfied: llama-cpp-python==0.1.77 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 60)) (0.1.77)
# Requirement already satisfied: MarkupSafe==2.1.3 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 61)) (2.1.3)
# Requirement already satisfied: marshmallow==3.20.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 62)) (3.20.1)
# Requirement already satisfied: matplotlib==3.7.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 63)) (3.7.2)
# Requirement already satisfied: matplotlib-inline==0.1.6 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 64)) (0.1.6)
# Requirement already satisfied: monotonic==1.6 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 65)) (1.6)
# Requirement already satisfied: mpmath==1.3.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 66)) (1.3.0)
# Requirement already satisfied: multidict==6.0.4 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 67)) (6.0.4)
# Requirement already satisfied: mypy-extensions==1.0.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 68)) (1.0.0)
# Requirement already satisfied: nest-asyncio==1.5.7 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 69)) (1.5.7)
# Requirement already satisfied: networkx==3.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 70)) (3.1)
# Requirement already satisfied: nltk==3.8.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 71)) (3.8.1)
# Requirement already satisfied: numexpr==2.8.5 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 72)) (2.8.5)
# Requirement already satisfied: numpy==1.25.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 73)) (1.25.2)
# Requirement already satisfied: onnxruntime==1.15.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 74)) (1.15.1)
# Requirement already satisfied: orjson==3.9.5 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 75)) (3.9.5)
# Requirement already satisfied: overrides==7.4.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 76)) (7.4.0)
# Requirement already satisfied: packaging==23.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 77)) (23.1)
# Requirement already satisfied: pandas==2.0.3 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 78)) (2.0.3)
# Requirement already satisfied: parso==0.8.3 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 79)) (0.8.3)
# Requirement already satisfied: pexpect==4.8.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 80)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 81)) (0.7.5)
# Requirement already satisfied: Pillow==10.0.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 82)) (10.0.0)
# Requirement already satisfied: platformdirs==3.10.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 83)) (3.10.0)
# Requirement already satisfied: posthog==3.0.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 84)) (3.0.2)
# Requirement already satisfied: prompt-toolkit==3.0.39 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 85)) (3.0.39)
# Requirement already satisfied: protobuf==4.24.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 86)) (4.24.2)
# Requirement already satisfied: psutil==5.9.5 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 87)) (5.9.5)
# Requirement already satisfied: ptyprocess==0.7.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 88)) (0.7.0)
# Requirement already satisfied: pulsar-client==3.2.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 89)) (3.2.0)
# Requirement already satisfied: pure-eval==0.2.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 90)) (0.2.2)
# Requirement already satisfied: py-cpuinfo==9.0.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 91)) (9.0.0)
# Requirement already satisfied: pydantic==1.10.12 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 92)) (1.10.12)
# Requirement already satisfied: pydantic_core==2.6.3 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 93)) (2.6.3)
# Requirement already satisfied: pydub==0.25.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 94)) (0.25.1)
# Requirement already satisfied: Pygments==2.16.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 95)) (2.16.1)
# Requirement already satisfied: PyMuPDF==1.23.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 96)) (1.23.1)
# Requirement already satisfied: PyMuPDFb==1.23.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 97)) (1.23.0)
# Requirement already satisfied: pyparsing==3.0.9 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 98)) (3.0.9)
# Requirement already satisfied: PyPika==0.48.9 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 99)) (0.48.9)
# Requirement already satisfied: python-dateutil==2.8.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 100)) (2.8.2)
# Requirement already satisfied: python-dotenv==1.0.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 101)) (1.0.0)
# Requirement already satisfied: python-multipart==0.0.6 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 102)) (0.0.6)
# Requirement already satisfied: pytz==2023.3 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 103)) (2023.3)
# Requirement already satisfied: PyYAML==6.0.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 104)) (6.0.1)
# Requirement already satisfied: pyzmq==25.1.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 105)) (25.1.1)
# Requirement already satisfied: referencing==0.30.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 106)) (0.30.2)
# Requirement already satisfied: regex==2023.8.8 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 107)) (2023.8.8)
# Requirement already satisfied: requests==2.31.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 108)) (2.31.0)
# Requirement already satisfied: rpds-py==0.9.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 109)) (0.9.2)
# Requirement already satisfied: safetensors==0.3.3 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 110)) (0.3.3)
# Requirement already satisfied: scikit-learn==1.3.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 111)) (1.3.0)
# Requirement already satisfied: scipy==1.11.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 112)) (1.11.2)
# Requirement already satisfied: semantic-version==2.10.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 113)) (2.10.0)
# Requirement already satisfied: sentence-transformers==2.2.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 114)) (2.2.2)
# Requirement already satisfied: sentencepiece==0.1.99 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 115)) (0.1.99)
# Requirement already satisfied: six==1.16.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 116)) (1.16.0)
# Requirement already satisfied: sniffio==1.3.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 117)) (1.3.0)
# Requirement already satisfied: SQLAlchemy==2.0.20 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 118)) (2.0.20)
# Requirement already satisfied: stack-data==0.6.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 119)) (0.6.2)
# Requirement already satisfied: starlette==0.27.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 120)) (0.27.0)
# Requirement already satisfied: sympy==1.12 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 121)) (1.12)
# Requirement already satisfied: tenacity==8.2.3 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 122)) (8.2.3)
# Requirement already satisfied: threadpoolctl==3.2.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 123)) (3.2.0)
# Requirement already satisfied: tokenizers==0.13.3 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 124)) (0.13.3)
# Requirement already satisfied: toolz==0.12.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 125)) (0.12.0)
# Requirement already satisfied: torch==2.0.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 126)) (2.0.1)
# Requirement already satisfied: torchvision==0.15.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 127)) (0.15.2)
# Requirement already satisfied: tornado==6.3.3 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 128)) (6.3.3)
# Requirement already satisfied: tqdm==4.66.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 129)) (4.66.1)
# Requirement already satisfied: traitlets==5.9.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 130)) (5.9.0)
# Requirement already satisfied: transformers==4.32.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 131)) (4.32.0)
# Requirement already satisfied: typing-inspect==0.9.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 132)) (0.9.0)
# Requirement already satisfied: typing_extensions==4.7.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 133)) (4.7.1)
# Requirement already satisfied: tzdata==2023.3 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 134)) (2023.3)
# Requirement already satisfied: urllib3==2.0.4 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 135)) (2.0.4)
# Requirement already satisfied: uvicorn==0.23.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 136)) (0.23.2)
# Requirement already satisfied: uvloop==0.17.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 137)) (0.17.0)
# Requirement already satisfied: watchfiles==0.20.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 138)) (0.20.0)
# Requirement already satisfied: wcwidth==0.2.6 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 139)) (0.2.6)
# Requirement already satisfied: websockets==11.0.3 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 140)) (11.0.3)
# Requirement already satisfied: widgetsnbextension==4.0.8 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 141)) (4.0.8)
# Requirement already satisfied: yarl==1.9.2 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from -r ../requirements.txt (line 142)) (1.9.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch==2.0.1->-r ../requirements.txt (line 126)) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch==2.0.1->-r ../requirements.txt (line 126)) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch==2.0.1->-r ../requirements.txt (line 126)) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch==2.0.1->-r ../requirements.txt (line 126)) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch==2.0.1->-r ../requirements.txt (line 126)) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch==2.0.1->-r ../requirements.txt (line 126)) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch==2.0.1->-r ../requirements.txt (line 126)) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch==2.0.1->-r ../requirements.txt (line 126)) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch==2.0.1->-r ../requirements.txt (line 126)) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch==2.0.1->-r ../requirements.txt (line 126)) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch==2.0.1->-r ../requirements.txt (line 126)) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch==2.0.1->-r ../requirements.txt (line 126)) (2.0.0)
# Requirement already satisfied: setuptools in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->-r ../requirements.txt (line 126)) (65.5.0)
# Requirement already satisfied: wheel in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->-r ../requirements.txt (line 126)) (0.43.0)
# Requirement already satisfied: cmake in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from triton==2.0.0->torch==2.0.1->-r ../requirements.txt (line 126)) (3.29.2)
# Requirement already satisfied: lit in /home/jakunzler/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from triton==2.0.0->torch==2.0.1->-r ../requirements.txt (line 126)) (18.1.3)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importar Módulos Langchain
from langchain.document_loaders import PyMuPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings.sentence_transformer import SentenceTransformerEmbeddings
from langchain.vectorstores import Chroma
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA
from langchain.llms import LlamaCpp, CTransformers

# Importar módulo para Front-End Web
import gradio as gr

# Importar módulo para carregar variáveis de ambiente do projeto
from dotenv import load_dotenv
import os

# %%
class ChatPDF:

    def __init__(self, documents_folder: str, vectordb_folder: str, model_path: str, sentence_embedding_model: str, temperature: float = 0.1):
        """
        Constrói todos os atributos necessários para o objeto ChatPDF

        Args:
            documents_folder (str): Caminho/Pasta com os documentos que serão carregados para conversação no Chat
            vectordb_folder (str): Caminho/Pasta onde ficarão os arquivos do Chroma (Vector DB)
            model_path (str): Caminho/Pasta que aponta para o modelo LLM a ser utilizado
            sentence_embedding_model (str): Nome do modelo de Embedding que será usado para gerar os tokens dos documentos
            temperature (float, optional): Temperatura para calibrar o nível de aleatoriedade das respostas. O padrão é 0.1 (Muito determinístico, pouco aleatório)
        """
        self.documents_folder = documents_folder
        self.vectordb_folder = vectordb_folder
        self.model_path = model_path
        self.sentence_embedding_model = sentence_embedding_model
        self.temperature = temperature
        self.pages = []
        self.chunks = []

    def load(self) -> int:
        """
        Realiza a carga dos documentos do caminho/pasta definido no atributo documents_folder.

        Returns:
            int: Quantidade total de páginas carregadas de todos os arquivos PDF
        """

        loader = DirectoryLoader(
            self.documents_folder,
            glob="**/*.pdf",
            loader_cls=PyMuPDFLoader,
            show_progress=True,
            use_multithreading=True
        )

        self.pages = loader.load()

        return len(self.pages)
    
    def split(self, chunk_size: int = 1500, chunk_overlap: int = 150) -> int:
        """
        Realiza o split das páginas em chunks para armazenar no Vector DB

        Args:
            chunk_size (int, optional): Quantidade máxima de caracteres de cada chunk. O padrão é 1500.
            chunk_overlap (int, optional): Quantidade de caracteres de overlap entre chunks. O padrão é 150.

        Returns:
            int: Quantidade total de chunks de todas as páginas de todos os documentos carregados
        """

        text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=chunk_size,
            chunk_overlap=chunk_overlap
        )

        self.chunks = text_splitter.split_documents(self.pages)

        return len(self.chunks)
    
    def get_embeddings(self):
        """
        Obtem os embeddings do modelo de linguagem definido no atributo sentence_embedding_model.
        """
        self.embeddings = SentenceTransformerEmbeddings(model_name=self.sentence_embedding_model)

    def store(self):
        """
        Armazena os chunks de todos os documentos no Vector DB, utilizando o embedding definido. 
        """
        vectordb = Chroma.from_documents(
            documents=self.chunks,
            embedding=self.embeddings,
            persist_directory=self.vectordb_folder
        )

        vectordb.persist()

        self.vectordb = vectordb

    def create_llm(self):
        """
        Cria uma LLM local, com base no modelo definido no atributo model_path.
        """
        
        self.llm = LlamaCpp(model_path=self.model_path, verbose=True, n_ctx=2048, temperature=self.temperature)

    def create_retriever(self):
        """
        Cria um retriever de documentos com base do Vector DB já carregado com os documentos.
        """
        self.retriever = self.vectordb.as_retriever(search_kwargs={'k': 2})

    def create_qa_session(self):
        """
        Cria uma sessão de QA, usando o LLM e Retriever já instanciados.
        """

        PROMPT_TEMPLATE = """
        Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to male up an answer. Use three sentences maximum. Keep answer as concise as possible. Always say "thanks for asking! at the end of the answer.
        {context}
        Question: {question}
        Helpful Answer:"""

        QA_CHAIN_PROMPT = PromptTemplate.from_template(PROMPT_TEMPLATE)

        self.qa = RetrievalQA.from_chain_type(
            self.llm,
            'stuff',
            retriever=self.retriever,
            return_source_documents=True,
            chain_type_kwargs={'prompt': QA_CHAIN_PROMPT}
        )

# %%
# Carrega as variáveis de ambiente do arquivo .env, para utilizar na hora de parametrizar o objeto ChatPDF
load_dotenv()

MODEL_PATH = os.getenv('MODEL_PATH')
VECTORDB_FOLDER = os.getenv('VECTORDB_FOLDER')
DOCUMENTS_FOLDER = os.getenv('DOCUMENTS_FOLDER')
SENTENCE_EMBEDDING_MODEL = os.getenv('SENTENCE_EMBEDDING_MODEL')

# %%
# Cria um objeto ChatPDF
chat = ChatPDF(DOCUMENTS_FOLDER, VECTORDB_FOLDER, MODEL_PATH, SENTENCE_EMBEDDING_MODEL, temperature=0.3)

# %%
# Executa a carga dos documentos PDF que iremos interagir na sessão de Chat Q&A
chat.load()

# %%
# Executa o split dos documentos carregados
chat.split()

# %%
# Obtem os embeddings do modelo de linguagem selecionado
chat.get_embeddings()

# %%
# Armazena os chunks dos documentos, junto com o embedding, no Vector DB (Chroma)
chat.store()

# %%
# Cria a LLM (LLAMA V2) localmente para interagirmos na sessão de chat
chat.create_llm()

# %%
# Cria o retriever, que irá recuperar os documentos do Vector DB, com base nos Prompts e usando a LLM
chat.create_retriever()

# %%
# Cria uma sessão de chat para Q&A, com base no LLM e Retriever
chat.create_qa_session()

# %%
# Front-End da Aplicação Web - Gradio

chat_history = []

with gr.Blocks() as demo:

    chatbot = gr.Chatbot()
    msg = gr.Textbox()
    clear = gr.Button("Clear")

    chat_history = []
    
    def user(user_message, chat_history):
        
        # Retorna resposta da LLM, através da sessão de Q&A
        result = chat.qa({"query": user_message})
        
        # Realiza um append na tela do chat, contendo a mensagem do usuário e a resposta do modelo
        chat_history.append((user_message, result["result"]))

        return gr.update(value=""), chat_history
    
    msg.submit(user, [msg, chatbot], [msg, chatbot], queue=False)
    clear.click(lambda: None, None, chatbot, queue=False)

if __name__ == "__main__":
    demo.launch(debug=True)
